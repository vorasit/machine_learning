# %% [markdown]
# # Classification 1: (Fruit 2 classes)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Dataset

# %%
X = [[27],                                                              
     [35],                                                              
     [39],                                                              
     [21],                                                              
     [22],                                                                   
     [45]]                                                              

y_names = ['lemon', 'orange', 'orange', 'lemon', 'lemon', 'orange']
y = [0, 1, 1, 0, 0, 1]

# %%
from IPython.display import Image
Image(filename='images/ch08/decisiontree1.png')

# %% [markdown]
# ## Data Visualization

# %%
# plt.figure(figsize=(4,3))

plt.xlabel('fruit')
plt.ylabel('size')
plt.scatter(y_names, X)
plt.show()

# %% [markdown]
# # Model
# https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()

# %%
Image(filename='images/ch08/classification1-train-sm.png')

# %%
model.fit(X, y)
# Out:
# DecisionTreeClassifier()

# %%
Image(filename='images/ch08/decisiontree1.png')

# %% [markdown]
# ## Predict

# %%
Image(filename='images/ch08/classification1-predict.png')

# %%
X_input = [[25.3]]
y_predict = model.predict(X_input)
y_predict
# print('Result =', y_predict[0] )
# Out:
# array([0])

# %%
fruit_classes = ['Lemon','Orange']

# %%
prd = fruit_classes[y_predict[0]]
print('Result: {}'. format(prd))
# Out:
# Result: Lemon

# %%
X_input = [[31.0],
           [25.0],
           [21.2],
           [38.6]]
y_predict = model.predict(X_input)
y_predict
# Out:
# array([0, 0, 0, 1])

# %%
print('Result:')
for i in y_predict:
    print(fruit_classes[i])
# Out:
# Result:
# Lemon
# Lemon
# Lemon
# Orange

# %%
for i, val in enumerate(y_predict):
    print(f'{X_input[i]} = {val}  {fruit_classes[val]}')
# Out:
# [31.0] = 0  Lemon
# [25.0] = 0  Lemon
# [21.2] = 0  Lemon
# [38.6] = 1  Orange

# %% [markdown]
# ## Visualize Model
# - Tree
# - ขอบเขตการแบ่ง (การตัดสินใจ)

# %% [markdown]
# ### Tree
# - scikit learn v >= .21
# - python-graphviz + pydotplus (Optional)

# %%
# !pip show scikit-learn

# %%
# !conda list scikit-learn

# %%
from sklearn.tree import plot_tree

data_feature_names = ['size']

plt.subplots(nrows=1, ncols=1, figsize=(4, 3), dpi=96)
# plt.figure(figsize=(6,6))

plot_tree(model, 
         filled=True, rounded=True,
         feature_names=data_feature_names,  
         class_names=fruit_classes)

plt.show()

# %%
plot_tree(model)
# Out:
# [Text(167.4, 163.07999999999998, 'X[0] <= 31.0\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(83.7, 54.360000000000014, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(251.10000000000002, 54.360000000000014, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]')]

# %%
import pydotplus
from sklearn.tree import export_graphviz
from IPython.display import Image

data_feature_names = ['size']

dot_data = export_graphviz(model, out_file=None, 
                           feature_names=data_feature_names,  
                           class_names=fruit_classes, 
                           filled=True,
                           rounded=True)

graph = pydotplus.graph_from_dot_data(dot_data)  
Image(graph.create_png())

# %% [markdown]
# ### ขอบเขตการแบ่ง (การตัดสินใจ: Decision regions)

# %%
# !pip show mlxtend

# %%
# !pip install mlxtend

# %%
from mlxtend.plotting import plot_decision_regions

# %%
# plot needs Numpy
X = np.array(X)
y = np.array(y)

# %%
# Plot
plot_decision_regions(X, y, clf=model)
plt.show()

# %%
X_input_size = 25
if (X_input_size <= 31):
    fruit = 'Lemon'
else:
    fruit = 'Orange'
    
print(fruit)
# Out:
# Lemon

# %% [markdown]
# # Classification 2: (Fruit 3 classes)
# Lemon, Orange and Pomelo

# %% [markdown]
# ## Dataset

# %%
X = [[27],                                                              
     [35],                                                              
     [39],                                                              
     [21],                                                              
     [22],                                                                   
     [45],
     [102],
     [110],
     [120] ]                                                              

y_names = ['lemon', 'orange', 'orange', 'lemon', 'lemon', 'orange', 'pamelo', 'pamelo', 'pamelo']
y = [0, 1, 1, 0, 0, 1, 2, 2, 2]

# %% [markdown]
# ## Data Visualization

# %%
plt.xlabel('fruit')
plt.ylabel('size')

plt.scatter(y_names, X)
plt.show()

# %% [markdown]
# ## Model

# %%
model = DecisionTreeClassifier()
model.fit(X, y)
# Out:
# DecisionTreeClassifier()

# %%
fruit_classes = ['Lemon','Orange', 'Pamelo']

# %% [markdown]
# ## Predict

# %%
X_input = [[102]]
y_predict = model.predict(X_input)

prd = fruit_classes[y_predict[0]]
print('Result : {}'. format(prd))
# Out:
# Result : Pamelo

# %%
X_input = [[28],                                                              
     [32],                                                              
     [39],                                                              
     [101]]

y_predict = model.predict(X_input)

y_predict
# class_names[y_predict]
# prd = class_names[y_predict[0]]
# print('Result : {}'. format(prd))
# Out:
# array([0, 1, 1, 2])

# %%
for i, k in enumerate(y_predict):
    print(f'{X_input[i]} = {fruit_classes[k]}')
# Out:
# [28] = Lemon
# [32] = Orange
# [39] = Orange
# [101] = Pamelo

# %% [markdown]
# ## Visualize Model

# %% [markdown]
# ### Tree

# %%
from sklearn.tree import plot_tree

data_feature_names = ['size']

plt.subplots(nrows=1, ncols=1, figsize=(5, 4), dpi=96)
# plt.figure(figsize=(6,6))

plot_tree(model, 
         filled=True, rounded=True,
         feature_names=data_feature_names,  
         class_names=fruit_classes)

plt.show()

# %%
X_input_size = 72.4
if (X_input_size <= 31):
    fruit = 'Lemon'
elif (X_input_size <= 73.5):
    fruit = 'Orange'
else:
    fruit = 'Pomelo'
    
print(fruit)

# %% [markdown]
# ### Decision regions

# %%
from mlxtend.plotting import plot_decision_regions

# %%
# plot needs Numpy
X = np.array(X)
y = np.array(y)

# %%
plot_decision_regions(X, y, clf=model)
plt.show()
